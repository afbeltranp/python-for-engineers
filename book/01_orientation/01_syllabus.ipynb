# %% [markdown]
# # Plan de Estudios
#
# Explora la estructura completa del curso, políticas de calificación, horarios de oficina y más:
#
# <div align="center">
#
# [![Ver el Plan de Estudios](https://img.shields.io/badge/Ver%20Plan%20de%20Estudios-blue?style=for-the-badge&logo=readthedocs)]()
#
# </div>
#
# ---
#
# ### 📚 Descripción General
# - Instructor: Dr. Andrés Felipe Beltrán Pulido
# - Módulos semanales con formulario de autorregulación, teoría, demostraciones, laboratorios, quizzes
# - Microsoft Teams requerido para los quizzes
# - Los exámenes son presenciales
# - Comunicación a través de Microsoft Teams
# - No se admiten tareas atrasadas
# - Circunstancias especiales podrían otorgar una extensión, sin embargo, tendrás que enviar documentación para ello.
#
#
# ---
#
# ### 📖 Materiales
# - Requeridos: Microsoft Teams, Python, Visual Studio Code (VSCode)

# %%
# import json
# from jupyterquiz import display_quiz
# with open("jquiz1.json", "r") as file:
#     questions=json.load(file)

# display_quiz(questions,  border_radius=0)
