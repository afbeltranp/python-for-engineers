# %% [markdown]
# # Variables
#
# ### **Learning Objectives**
# - ✅ Learn what is a variable in Python.
# - ✅ Understand what simple variable types exist in Python.
# - ✅ Use variables to store information.
#
# ---
#
# ### **What is a Variable in Python?**
# A variable in Python acts like a storage box that holds data. It's a label you can attach to a value, which allows you to recall and modify it at any point in your program. For instance, if you create a variable `age` and assign it the value `25` using `age = 25`, you've just stored the number `25` in a "box" labeled `age`.
#
# ---
#
# ### **Understand What Simple Variable Types Exist in Python**
# Python supports several basic types of variables to handle different kinds of information. Here are a few:
#
# - **Integers (`int`)**: Whole numbers without decimal points, such as `7` or `-3`.
# - **Floats (`float`)**: Real numbers with decimal points, like `3.14` or `-0.001`.
# - **Strings (`str`)**: Sequences of characters for text, enclosed in quotes like `"Hello, world!"`.
# - **Booleans (`bool`)**: Represents truth values, either `True` or `False`.
#
# ---
#
# ### **Use Variables to Store Information**
# Variables help make your code flexible and readable. By using them to store information, you can update the data without changing the rest of the program. For example, if you have a variable `temperature = 75`, and the weather changes, you can update it like this: `temperature = 68`. This keeps your code dynamic, reflecting the latest state without needing to recreate the variable.
#
# ---
#
# ### **Question: Cat Variable**
# To complete the code in `variables.py`, follow these steps:
#
# 1. Define the variable `cat` with the string `"cat"` on the first line. This ensures the first `print(cat)` outputs `"cat"`.
# 2. Update the variable `cat` to hold the integer `79` so that the second `print(cat)` outputs `79`.
# 3. Update the variable `cat` to hold the boolean value `True` so that the third `print(cat)` outputs `True`.
#
# After completing the task, click **Check it!** to submit your solution.

# %%
# %%capture cap
# variables.py

# IMPORTANT: DO NOT edit the print statements surrounded by "FREEZE CODE BEGIN" and "FREEZE CODE END".

#TODO: Define the variable cat with the string "cat".
cat = "cat"

# FREEZE CODE BEGIN
print(cat)
# FREEZE CODE END

#TODO: Update the variable cat to hold the integer 79.
cat = 79

# FREEZE CODE BEGIN
print(cat)
# FREEZE CODE END

#TODO: Update the variable cat to hold the boolean value True.
cat = True

#FREEZE CODE BEGIN
print(cat)
# FREEZE CODE END

# %%
import ipywidgets as widgets
from IPython.display import display

def check_it(actual, expected_stdout="cat\n79\nTrue\n"):
    out = widgets.Output()
    btn = widgets.Button(description="Check it!")

    def _check(_):
        with out:
            out.clear_output()

            if actual == expected_stdout:
                print("Correct!")
            else:
                print("Incorrect!")

    btn.on_click(_check)
    display(btn, out)

# %%
check_it(cap.stdout)
# Out:
# Button(description='Check it!', style=ButtonStyle())
# Output()
