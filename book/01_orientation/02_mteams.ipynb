# %% [markdown]
# # Microsoft Teams
#
# 💬 Únete a Microsoft Teams del Curso
#
# ## 📢 Tu Centro Principal
#
# Microsoft Teams será, por mucho, tu mejor herramienta cuando se trate de obtener ayuda este semestre. Fuera del horario de consulta, esta será la forma más rápida de obtener una respuesta para cualquier pregunta sobre python, tareas o calificaciones. **¡Siempre que tengas alguna pregunta, solo pregunta en Teams!**
#
# ### Canal de Preguntas
#
# ![Una imagen del Canal de Preguntas de Teams](qc.png)
#
# Como se ve en esta captura de pantalla, el canal de preguntas es una forma para que los estudiantes publiquen sus **inquietudes sobre calificaciones/curso** en un estilo de foro. ¡Las preguntas inicialmente serán marcadas por su estado y categoría para asegurarse de que el personal del curso vea tu inquietud y la atienda lo antes posible!
#
# ### Canal de Preguntas sobre Tareas
#
# ![Una imagen del Canal de Preguntas sobre Tareas de Teams](aqc.png)
#
# Similar al canal de Preguntas, este espacio es para hacer preguntas sobre tus tareas. La diferencia clave es que está organizado en categorías para cada tarea actual y está destinado específicamente a preguntas sobre especificaciones de tareas y problemas relacionados con el código. **Por favor, no publiques ningún código en ningún momento.**
#
# Como equipo de instrucción, podemos ver tu código enviado. Esto significa que si describes el problema que estás experimentando (por ejemplo, "Estoy teniendo problemas con X en la Tarea Y debido a Z"), podemos revisar tu código directamente y ayudarte, sin que necesites compartir ningún código en el canal.
#
# ### Canal de Servicios Estudiantiles
#
# Un lugar para que solicites una extensión en una tarea dada una razón específica. Esto será enviado al personal del curso para su aprobación redirigiéndote a un formulario de solicitud para que lo completes. ![El widget a usar para una extensión de tarea por una razón válida](requestExt.png)|

# %%
# import json
# from jupyterquiz import display_quiz
# with open("jquiz1.json", "r") as file:
#     questions=json.load(file)

# display_quiz(questions,  border_radius=0)
